# %% [markdown]
# ## What's this TensorFlow business?
#
# You've written a lot of code in this assignment to provide a whole host of neural network functionality. Dropout, Batch Norm, and 2D convolutions are some of the workhorses of deep learning in computer vision. You've also worked hard to make your code efficient and vectorized.
#
# For the last part of this assignment, though, we're going to leave behind your beautiful codebase and instead migrate to one of two popular deep learning frameworks: in this instance, TensorFlow (or PyTorch, if you switch over to that notebook)
#
# #### What is it?
# TensorFlow is a system for executing computational graphs over Tensor objects, with native support for performing backpropogation for its Variables. In it, we work with Tensors which are n-dimensional arrays analogous to the numpy ndarray.
#
# #### Why?
#
# * Our code will now run on GPUs! Much faster training. Writing your own modules to run on GPUs is beyond the scope of this class, unfortunately.
# * We want you to be ready to use one of these frameworks for your project so you can experiment more efficiently than if you were writing every feature you want to use by hand.
# * We want you to stand on the shoulders of giants! TensorFlow and PyTorch are both excellent frameworks that will make your lives a lot easier, and now that you understand their guts, you are free to use them :)
# * We want you to be exposed to the sort of deep learning code you might run into in academia or industry.

# %% [markdown]
# ## How will I learn TensorFlow?
#
# TensorFlow has many excellent tutorials available, including those from [Google themselves](https://www.tensorflow.org/get_started/get_started).
#
# Otherwise, this notebook will walk you through much of what you need to do to train models in TensorFlow. See the end of the notebook for some links to helpful tutorials if you want to learn more or need further clarification on topics that aren't fully explained here.

# %% [markdown]
# ## Load Datasets

# %%
import tensorflow as tf
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=10000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %% [markdown]
# ## Example Model
#
# ### Some useful utilities
#
# . Remember that our image data is initially N x H x W x C, where:
# * N is the number of datapoints
# * H is the height of each image in pixels
# * W is the height of each image in pixels
# * C is the number of channels (usually 3: R, G, B)
#
# This is the right way to represent the data when we are doing something like a 2D convolution, which needs spatial understanding of where the pixels are relative to each other. When we input image data into fully connected affine layers, however, we want each data example to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data.

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in TensorFlow -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.
#
# In that example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Hinge loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 5408 and 10.
#
# ### TensorFlow Details
# In TensorFlow, much like in our previous notebooks, we'll first specifically initialize our variables, and then our network model.

# %%
# clear old variables
tf.reset_default_graph()

# setup input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)
keep_prob = tf.placeholder(tf.float32)

def simple_model(X,y):
    # define our weights (e.g. init_two_layer_convnet)
    
    # setup variables
    Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    W1 = tf.get_variable("W1", shape=[5408, 10])
    b1 = tf.get_variable("b1", shape=[10])

    # define our graph (e.g. two_layer_convnet)
    a1 = tf.nn.conv2d(X, Wconv1, strides=[1,2,2,1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    h1_flat = tf.reshape(h1,[-1,5408])
    y_out = tf.matmul(h1_flat,W1) + b1
    return y_out

y_out = simple_model(X,y)

# define our loss
total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
mean_loss = tf.reduce_mean(total_loss)

# define our optimizer
optimizer = tf.train.AdamOptimizer(5e-4) # select optimizer and set learning rate
train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# TensorFlow supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful).
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/batch_normalization

# %% [markdown]
# ### Training the model on one epoch
# While we have defined a graph of operations above, in order to execute TensorFlow Graphs, by feeding them input data and computing the results, we first need to create a `tf.Session` object. A session encapsulates the control and state of the TensorFlow runtime. For more information, see the TensorFlow [Getting started](https://www.tensorflow.org/get_started/get_started) guide.
#
# Optionally we can also specify a device context such as `/cpu:0` or `/gpu:0`. For documentation on this behavior see [this TensorFlow guide](https://www.tensorflow.org/tutorials/using_gpu)
#
# You should see a validation loss of around 0.4 to 0.6 and an accuracy of 0.30 to 0.35 below

# %%
def run_model(session, predict, loss_val, Xd, yd,
              epochs=1, batch_size=64, print_every=100,
              training=None, plot_losses=False, _keep_prob=1.0):
    # have tensorflow compute accuracy
    correct_prediction = tf.equal(tf.argmax(predict,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies
    train_indicies = np.arange(Xd.shape[0])
    np.random.shuffle(train_indicies)

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss,correct_prediction,accuracy]
    if training_now:
        variables[-1] = training
    
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        # keep track of losses and accuracy
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {X: Xd[idx,:],
                         y: yd[idx],
                         is_training: training_now,
                         keep_prob: _keep_prob}
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
            
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
            iter_cnt += 1
        total_correct = correct/Xd.shape[0]
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
    return total_loss,total_correct

with tf.Session() as sess:
    with tf.device("/cpu:0"): #"/cpu:0" or "/gpu:0" 
        sess.run(tf.global_variables_initializer())
        print('Training')
        run_model(sess,y_out,mean_loss,X_train,y_train,1,64,100,train_step,True)
        print('Validation')
        run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 9.98 and accuracy of 0.11
# Iteration 100: with minibatch training loss = 0.955 and accuracy of 0.17
# Iteration 200: with minibatch training loss = 0.677 and accuracy of 0.28
# Iteration 300: with minibatch training loss = 0.716 and accuracy of 0.25
# Iteration 400: with minibatch training loss = 0.575 and accuracy of 0.34
# Iteration 500: with minibatch training loss = 0.519 and accuracy of 0.23
# Iteration 600: with minibatch training loss = 0.375 and accuracy of 0.5
# Iteration 700: with minibatch training loss = 0.398 and accuracy of 0.34
# Epoch 1, Overall loss = 0.746 and accuracy of 0.309
# Validation
# Epoch 1, Overall loss = 0.408 and accuracy of 0.387

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the TensorFlow documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following TensorFlow documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 32 filters and stride of 1
# * ReLU Activation Layer
# * Spatial Batch Normalization Layer (trainable parameters, with scale and centering)
# * 2x2 Max Pooling layer with a stride of 2
# * Affine layer with 1024 output units
# * ReLU Activation Layer
# * Affine layer from 1024 input units to 10 outputs

# %%
# clear old variables
tf.reset_default_graph()

# define our input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)
keep_prob = tf.placeholder(tf.float32)

# define model
def complex_model(X,y,is_training):
    Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    W1 = tf.get_variable("W1", shape=[5408, 1024])
    b1 = tf.get_variable("b1", shape=[1024])
    W2 = tf.get_variable("W2", shape=[1024, 10])
    b2 = tf.get_variable("b2", shape=[10])
    
    conv_out1=tf.nn.conv2d(X, Wconv1, strides=[1,1,1,1], padding='VALID') + bconv1
    relu_out1=tf.nn.relu(conv_out1)
    bn_out1=tf.layers.batch_normalization(relu_out1,axis=3)
    pool_out1=tf.nn.max_pool(bn_out1,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID')
    data_flatten1=tf.reshape(pool_out1,[-1,5408])
    hidden_out1=tf.matmul(data_flatten1,W1)+b1
    relu_out2=tf.nn.relu(hidden_out1)
    y_out=tf.matmul(relu_out2,W2)+b2
    
    return y_out
    

y_out = complex_model(X,y,is_training)

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 64 x 10, since our batches have size 64 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
# Now we're going to feed a random batch into the model 
# and make sure the output is the right size
x = np.random.randn(64, 32, 32,3)
with tf.Session() as sess:
    with tf.device("/cpu:0"): #"/cpu:0" or "/gpu:0"
        tf.global_variables_initializer().run()

        ans = sess.run(y_out,feed_dict={X:x,is_training:True})
        # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
        print(ans.shape)
        print(np.array_equal(ans.shape, np.array([64, 10])))
# Out:
# 100 loops, best of 3: 2.46 ms per loop
# (64, 10)
# True

# %% [markdown]
# You should see the following from the run above
#
# `(64, 10)`
#
# `True`

# %% [markdown]
# ### GPU!
#
# Now, we're going to try and start the model under the GPU device, the rest of the code stays unchanged and all our variables and operations will be computed using accelerated code paths. However, if there is no GPU, we get a Python exception and have to rebuild our graph. On a dual-core CPU, you might see around 50-80ms/batch running the above, while the Google Cloud GPUs (run below) should be around 2-5ms/batch.

# %%
try:
    with tf.Session() as sess:
        with tf.device("/gpu:0") as dev: #"/cpu:0" or "/gpu:0"
            tf.global_variables_initializer().run()

            ans = sess.run(y_out,feed_dict={X:x,is_training:True})
            # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
except tf.errors.InvalidArgumentError:
    print("no gpu found, please use Google Cloud if you want GPU acceleration")    
    # rebuild the graph
    # trying to start a GPU throws an exception 
    # and also trashes the original graph
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y = tf.placeholder(tf.int64, [None])
    is_training = tf.placeholder(tf.bool)
    y_out = complex_model(X,y,is_training)
# Out:
# 100 loops, best of 3: 2.48 ms per loop

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use GPU devices. However, with TensorFlow, the default device is a GPU if one is available, and a CPU otherwise, so we can skip the device specification from now on.

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the complex_model you created provided above).
#
# Make sure you understand how each TensorFlow function used below corresponds to what you implemented in your custom neural network implementation.
#
# First, set up an **RMSprop optimizer** (using a 1e-3 learning rate) and a **cross-entropy loss** function. See the TensorFlow documentation for more information
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers

# %%
# Inputs
#     y_out: is what your model computes
#     y: is your TensorFlow variable with label information
# Outputs
#    mean_loss: a TensorFlow variable (scalar) with numerical loss
#    optimizer: a TensorFlow optimizer
# This should be ~3 lines of code!
mean_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_out,labels=tf.one_hot(y,10)))
optimizer = tf.train.RMSPropOptimizer(learning_rate=1e-3)

# %%
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# ### Train the model
# Below we'll create a session and train the model over one epoch. You should see a loss of 1.4 to 2.0 and an accuracy of 0.4 to 0.5. There will be some variation due to random seeds and differences in initialization

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())
print('Training')
run_model(sess,y_out,mean_loss,X_train,y_train,3,64,100,train_step)
# Out:
# Training
# Iteration 0: with minibatch training loss = 32.6 and accuracy of 0.11
# Iteration 100: with minibatch training loss = 6.35 and accuracy of 0.14
# Iteration 200: with minibatch training loss = 2.36 and accuracy of 0.2
# Iteration 300: with minibatch training loss = 2.16 and accuracy of 0.31
# Iteration 400: with minibatch training loss = 3.03 and accuracy of 0.23
# Iteration 500: with minibatch training loss = 1.72 and accuracy of 0.31
# Iteration 600: with minibatch training loss = 1.85 and accuracy of 0.38
# Iteration 700: with minibatch training loss = 1.54 and accuracy of 0.45
# Epoch 1, Overall loss = 3.85 and accuracy of 0.254
# Iteration 800: with minibatch training loss = 1.48 and accuracy of 0.5
# Iteration 900: with minibatch training loss = 1.64 and accuracy of 0.31
# Iteration 1000: with minibatch training loss = 1.49 and accuracy of 0.45
# Iteration 1100: with minibatch training loss = 1.53 and accuracy of 0.42
# Iteration 1200: with minibatch training loss = 1.8 and accuracy of 0.45
# Iteration 1300: with minibatch training loss = 1.83 and accuracy of 0.47
# Iteration 1400: with minibatch training loss = 1.52 and accuracy of 0.39
# Iteration 1500: with minibatch training loss = 1.51 and accuracy of 0.39
# Epoch 2, Overall loss = 1.63 and accuracy of 0.407
# Iteration 1600: with minibatch training loss = 1.34 and accuracy of 0.45
# Iteration 1700: with minibatch training loss = 1.51 and accuracy of 0.41
# Iteration 1800: with minibatch training loss = 1.64 and accuracy of 0.41
# Iteration 1900: with minibatch training loss = 1.49 and accuracy of 0.48
# Iteration 2000: with minibatch training loss = 1.69 and accuracy of 0.44
# Iteration 2100: with minibatch training loss = 1.34 and accuracy of 0.52
# Iteration 2200: with minibatch training loss = 1.31 and accuracy of 0.53
# Epoch 3, Overall loss = 1.47 and accuracy of 0.469
# (1.4724650186421919, 0.46946938775510205)

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and test code in action -- feel free to use these methods when evaluating the models you develop below. You should see a loss of 1.3 to 2.0 with an accuracy of 0.45 to 0.55.

# %%
print('Validation')
run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Validation
# Epoch 1, Overall loss = 1.46 and accuracy of 0.466
# (1.4641162738800049, 0.46600000000000003)

# %% [markdown]
# ## Train a _great_ model on CIFAR-10!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves ** >= 70% accuracy on the validation set** of CIFAR-10. You can use the `run_model` function from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Above we used 32 filters. Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Use TensorFlow Scope**: Use TensorFlow scope and/or [tf.layers](https://www.tensorflow.org/api_docs/python/tf/layers) to make it easier to write deeper networks. See [this tutorial](https://www.tensorflow.org/tutorials/layers) for how to use `tf.layers`.
# - **Use Learning Rate Decay**: [As the notes point out](http://cs231n.github.io/neural-networks-3/#anneal), decaying the learning rate might help the model converge. Feel free to decay every epoch, when loss doesn't change over an entire epoch, or any other heuristic you find appropriate. See the [Tensorflow documentation](https://www.tensorflow.org/versions/master/api_guides/python/train#Decaying_the_learning_rate) for learning rate decay.
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use [Dropout as in the TensorFlow MNIST tutorial](https://www.tensorflow.org/get_started/mnist/pros)
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and we'll save the test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try for extra credit.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at **>= 70% accuracy on the validation set**. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network. The final cell in this notebook should contain the training and validation set accuracies for your final trained network.
#
# Have fun and happy training!

# %%
# Feel free to play with this cell

def my_model(X,y,is_training,keep_prob):

    Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 64])
    bconv1 = tf.get_variable("bconv1", shape=[64])
    Wconv2 = tf.get_variable("Wconv2", shape=[5, 5, 64, 64])
    bconv2 = tf.get_variable("bconv2", shape=[64])
    W1 = tf.get_variable("W1", shape=[1024, 512])
    b1 = tf.get_variable("b1", shape=[512])
    W2 = tf.get_variable("W2", shape=[512, 10])
    b2 = tf.get_variable("b2", shape=[10])
    
    conv_out1=tf.nn.conv2d(X, Wconv1, strides=[1,1,1,1], padding='VALID') + bconv1
    bn_out1=tf.layers.batch_normalization(conv_out1,axis=3)
    relu_out1=tf.nn.relu(bn_out1)
    conv_out2=tf.nn.conv2d(relu_out1, Wconv2, strides=[1,3,3,1], padding='VALID') + bconv2
    bn_out2=tf.layers.batch_normalization(conv_out2,axis=3)
    relu_out2=tf.nn.relu(bn_out2)
    pool_out1=tf.nn.avg_pool(relu_out2,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID')
    data_flatten1=tf.reshape(pool_out1,[-1,1024])
    dropout1=tf.nn.dropout(data_flatten1,keep_prob)
    hidden_out1=tf.matmul(dropout1,W1)+b1
    bn_out3=tf.layers.batch_normalization(hidden_out1,axis=1)
    dropout2=tf.nn.dropout(bn_out3,keep_prob)
    relu_out3=tf.nn.relu(dropout2)
    y_out=tf.matmul(relu_out3,W2)+b2
    
    return y_out

tf.reset_default_graph()

X = tf.placeholder(tf.float32, [None, 32, 32, 3],name='X')
y = tf.placeholder(tf.int64, [None],name='Y')
is_training = tf.placeholder(tf.bool,name='is_training')
keep_prob = tf.placeholder(tf.float32,name='keep_prob')

y_out = my_model(X,y,is_training,keep_prob)
mean_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_out,labels=tf.one_hot(y,10)))
optimizer = tf.train.AdamOptimizer(learning_rate=5e-4)


pass

# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %%
# Feel free to play with this cell
# This default code creates a session
# and trains your model for 10 epochs
# then prints the validation set accuracy
sess = tf.Session()

sess.run(tf.global_variables_initializer())
for i in range(70):
    print('round ',i)
    print('Training')
    run_model(sess,y_out,mean_loss,X_train,y_train,1,64,100,train_step,False,0.5)
    print('Validation')
    run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# round  0
# Training
# Iteration 0: with minibatch training loss = 22.9 and accuracy of 0.062
# Iteration 100: with minibatch training loss = 2.2 and accuracy of 0.12
# Iteration 200: with minibatch training loss = 2.09 and accuracy of 0.2
# Iteration 300: with minibatch training loss = 2.02 and accuracy of 0.17
# Iteration 400: with minibatch training loss = 2.04 and accuracy of 0.22
# Iteration 500: with minibatch training loss = 2.02 and accuracy of 0.23
# Iteration 600: with minibatch training loss = 2.12 and accuracy of 0.2
# Iteration 700: with minibatch training loss = 2.01 and accuracy of 0.31
# Epoch 1, Overall loss = 2.18 and accuracy of 0.212
# Validation
# Epoch 1, Overall loss = 1.8 and accuracy of 0.345
# round  1
# Training
# Iteration 0: with minibatch training loss = 2.02 and accuracy of 0.22
# Iteration 100: with minibatch training loss = 2.04 and accuracy of 0.25
# Iteration 200: with minibatch training loss = 1.91 and accuracy of 0.28
# Iteration 300: with minibatch training loss = 1.67 and accuracy of 0.38
# Iteration 400: with minibatch training loss = 2.05 and accuracy of 0.27
# Iteration 500: with minibatch training loss = 1.83 and accuracy of 0.3
# Iteration 600: with minibatch training loss = 1.86 and accuracy of 0.36
# Iteration 700: with minibatch training loss = 1.72 and accuracy of 0.36
# Epoch 1, Overall loss = 1.88 and accuracy of 0.294
# Validation
# Epoch 1, Overall loss = 1.66 and accuracy of 0.423
# round  2
# Training
# Iteration 0: with minibatch training loss = 1.97 and accuracy of 0.3
# Iteration 100: with minibatch training loss = 1.83 and accuracy of 0.33
# Iteration 200: with minibatch training loss = 1.88 and accuracy of 0.28
# Iteration 300: with minibatch training loss = 2.07 and accuracy of 0.3
# Iteration 400: with minibatch training loss = 1.93 and accuracy of 0.34
# Iteration 500: with minibatch training loss = 1.75 and accuracy of 0.33
# Iteration 600: with minibatch training loss = 1.95 and accuracy of 0.42
# Iteration 700: with minibatch training loss = 1.76 and accuracy of 0.36
# Epoch 1, Overall loss = 1.76 and accuracy of 0.348
# Validation
# Epoch 1, Overall loss = 1.62 and accuracy of 0.422
# round  3
# Training
# Iteration 0: with minibatch training loss = 1.92 and accuracy of 0.3
# Iteration 100: with minibatch training loss = 1.58 and accuracy of 0.39
# Iteration 200: with minibatch training loss = 1.96 and accuracy of 0.28
# Iteration 300: with minibatch training loss = 1.82 and accuracy of 0.28
# Iteration 400: with minibatch training loss = 1.61 and accuracy of 0.41
# Iteration 500: with minibatch training loss = 1.64 and accuracy of 0.41
# Iteration 600: with minibatch training loss = 1.61 and accuracy of 0.47
# Iteration 700: with minibatch training loss = 1.56 and accuracy of 0.38
# Epoch 1, Overall loss = 1.65 and accuracy of 0.39
# Validation
# Epoch 1, Overall loss = 1.51 and accuracy of 0.499
# round  4
# Training
# Iteration 0: with minibatch training loss = 1.54 and accuracy of 0.47
# Iteration 100: with minibatch training loss = 1.57 and accuracy of 0.48
# Iteration 200: with minibatch training loss = 1.64 and accuracy of 0.36
# Iteration 300: with minibatch training loss = 1.74 and accuracy of 0.44
# Iteration 400: with minibatch training loss = 1.54 and accuracy of 0.34
# Iteration 500: with minibatch training loss = 1.42 and accuracy of 0.42
# Iteration 600: with minibatch training loss = 1.43 and accuracy of 0.48
# Iteration 700: with minibatch training loss = 1.78 and accuracy of 0.36
# Epoch 1, Overall loss = 1.58 and accuracy of 0.423
# Validation
# Epoch 1, Overall loss = 1.43 and accuracy of 0.528
# round  5
# Training
# Iteration 0: with minibatch training loss = 1.51 and accuracy of 0.5
# Iteration 100: with minibatch training loss = 1.43 and accuracy of 0.45
# Iteration 200: with minibatch training loss = 1.5 and accuracy of 0.44
# Iteration 300: with minibatch training loss = 1.49 and accuracy of 0.44
# Iteration 400: with minibatch training loss = 1.57 and accuracy of 0.42
# Iteration 500: with minibatch training loss = 1.46 and accuracy of 0.5
# Iteration 600: with minibatch training loss = 1.33 and accuracy of 0.53
# Iteration 700: with minibatch training loss = 1.48 and accuracy of 0.53
# Epoch 1, Overall loss = 1.5 and accuracy of 0.455
# Validation
# Epoch 1, Overall loss = 1.39 and accuracy of 0.555
# round  6
# Training
# Iteration 0: with minibatch training loss = 1.29 and accuracy of 0.58
# Iteration 100: with minibatch training loss = 1.47 and accuracy of 0.44
# Iteration 200: with minibatch training loss = 1.46 and accuracy of 0.47
# Iteration 300: with minibatch training loss = 1.55 and accuracy of 0.45
# Iteration 400: with minibatch training loss = 1.6 and accuracy of 0.41
# Iteration 500: with minibatch training loss = 1.36 and accuracy of 0.44
# Iteration 600: with minibatch training loss = 1.33 and accuracy of 0.56
# Iteration 700: with minibatch training loss = 1.27 and accuracy of 0.5
# Epoch 1, Overall loss = 1.45 and accuracy of 0.48
# Validation
# Epoch 1, Overall loss = 1.3 and accuracy of 0.576
# round  7
# Training
# Iteration 0: with minibatch training loss = 1.36 and accuracy of 0.47
# Iteration 100: with minibatch training loss = 1.44 and accuracy of 0.55
# Iteration 200: with minibatch training loss = 1.58 and accuracy of 0.44
# Iteration 300: with minibatch training loss = 1.29 and accuracy of 0.55
# Iteration 400: with minibatch training loss = 1.37 and accuracy of 0.53
# Iteration 500: with minibatch training loss = 1.38 and accuracy of 0.47
# Iteration 600: with minibatch training loss = 1.41 and accuracy of 0.53
# Iteration 700: with minibatch training loss = 1.12 and accuracy of 0.64
# Epoch 1, Overall loss = 1.41 and accuracy of 0.499
# Validation
# Epoch 1, Overall loss = 1.27 and accuracy of 0.57
# round  8
# Training
# Iteration 0: with minibatch training loss = 1.5 and accuracy of 0.47
# Iteration 100: with minibatch training loss = 1.27 and accuracy of 0.48
# Iteration 200: with minibatch training loss = 1.27 and accuracy of 0.53
# Iteration 300: with minibatch training loss = 1.25 and accuracy of 0.59
# Iteration 400: with minibatch training loss = 1.24 and accuracy of 0.59
# Iteration 500: with minibatch training loss = 1.31 and accuracy of 0.56
# Iteration 600: with minibatch training loss = 1.42 and accuracy of 0.5
# Iteration 700: with minibatch training loss = 1.43 and accuracy of 0.5
# Epoch 1, Overall loss = 1.38 and accuracy of 0.51
# Validation
# Epoch 1, Overall loss = 1.26 and accuracy of 0.594
# round  9
# Training
# Iteration 0: with minibatch training loss = 1.38 and accuracy of 0.52
# Iteration 100: with minibatch training loss = 1.2 and accuracy of 0.52
# Iteration 200: with minibatch training loss = 1.1 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 1.22 and accuracy of 0.45
# Iteration 400: with minibatch training loss = 1.04 and accuracy of 0.56
# Iteration 500: with minibatch training loss = 1.22 and accuracy of 0.52
# Iteration 600: with minibatch training loss = 1.58 and accuracy of 0.38
# Iteration 700: with minibatch training loss = 0.966 and accuracy of 0.75
# Epoch 1, Overall loss = 1.32 and accuracy of 0.529
# Validation
# Epoch 1, Overall loss = 1.21 and accuracy of 0.621
# round  10
# Training
# Iteration 0: with minibatch training loss = 1.26 and accuracy of 0.56
# Iteration 100: with minibatch training loss = 1.13 and accuracy of 0.56
# Iteration 200: with minibatch training loss = 1.16 and accuracy of 0.56
# Iteration 300: with minibatch training loss = 1.06 and accuracy of 0.59
# Iteration 400: with minibatch training loss = 1.2 and accuracy of 0.56
# Iteration 500: with minibatch training loss = 1.32 and accuracy of 0.61
# Iteration 600: with minibatch training loss = 1.26 and accuracy of 0.55
# Iteration 700: with minibatch training loss = 1.36 and accuracy of 0.47
# Epoch 1, Overall loss = 1.28 and accuracy of 0.546
# Validation
# Epoch 1, Overall loss = 1.13 and accuracy of 0.628
# round  11
# Training
# Iteration 0: with minibatch training loss = 1.07 and accuracy of 0.56
# Iteration 100: with minibatch training loss = 1.07 and accuracy of 0.66
# Iteration 200: with minibatch training loss = 1.38 and accuracy of 0.52
# Iteration 300: with minibatch training loss = 1.31 and accuracy of 0.64
# Iteration 400: with minibatch training loss = 1.44 and accuracy of 0.47
# Iteration 500: with minibatch training loss = 1.24 and accuracy of 0.48
# Iteration 600: with minibatch training loss = 1.13 and accuracy of 0.59
# Iteration 700: with minibatch training loss = 1.09 and accuracy of 0.56
# Epoch 1, Overall loss = 1.25 and accuracy of 0.558
# Validation
# Epoch 1, Overall loss = 1.12 and accuracy of 0.632
# round  12
# Training
# Iteration 0: with minibatch training loss = 1.21 and accuracy of 0.55
# Iteration 100: with minibatch training loss = 1.06 and accuracy of 0.53
# Iteration 200: with minibatch training loss = 1.14 and accuracy of 0.55
# Iteration 300: with minibatch training loss = 1.3 and accuracy of 0.53
# Iteration 400: with minibatch training loss = 1.4 and accuracy of 0.56
# Iteration 500: with minibatch training loss = 1.23 and accuracy of 0.64
# Iteration 600: with minibatch training loss = 1.16 and accuracy of 0.47
# Iteration 700: with minibatch training loss = 1.35 and accuracy of 0.52
# Epoch 1, Overall loss = 1.23 and accuracy of 0.565
# Validation
# Epoch 1, Overall loss = 1.11 and accuracy of 0.633
# round  13
# Training
# Iteration 0: with minibatch training loss = 0.99 and accuracy of 0.62
# Iteration 100: with minibatch training loss = 1.15 and accuracy of 0.48
# Iteration 200: with minibatch training loss = 1.2 and accuracy of 0.56
# Iteration 300: with minibatch training loss = 1.39 and accuracy of 0.56
# Iteration 400: with minibatch training loss = 1.39 and accuracy of 0.56
# Iteration 500: with minibatch training loss = 1.07 and accuracy of 0.58
# Iteration 600: with minibatch training loss = 1.35 and accuracy of 0.52
# Iteration 700: with minibatch training loss = 1.12 and accuracy of 0.52
# Epoch 1, Overall loss = 1.2 and accuracy of 0.576
# Validation
# Epoch 1, Overall loss = 1.09 and accuracy of 0.65
# round  14
# Training
# Iteration 0: with minibatch training loss = 1.29 and accuracy of 0.52
# Iteration 100: with minibatch training loss = 1.01 and accuracy of 0.59
# Iteration 200: with minibatch training loss = 1.13 and accuracy of 0.56
# Iteration 300: with minibatch training loss = 1.01 and accuracy of 0.56
# Iteration 400: with minibatch training loss = 1.17 and accuracy of 0.58
# Iteration 500: with minibatch training loss = 1.18 and accuracy of 0.62
# Iteration 600: with minibatch training loss = 1.1 and accuracy of 0.61
# Iteration 700: with minibatch training loss = 1.1 and accuracy of 0.58
# Epoch 1, Overall loss = 1.17 and accuracy of 0.585
# Validation
# Epoch 1, Overall loss = 1.06 and accuracy of 0.664
# round  15
# Training
# Iteration 0: with minibatch training loss = 1.2 and accuracy of 0.67
# Iteration 100: with minibatch training loss = 1.08 and accuracy of 0.64
# Iteration 200: with minibatch training loss = 1.36 and accuracy of 0.55
# Iteration 300: with minibatch training loss = 1.35 and accuracy of 0.53
# Iteration 400: with minibatch training loss = 1.22 and accuracy of 0.55
# Iteration 500: with minibatch training loss = 1.11 and accuracy of 0.64
# Iteration 600: with minibatch training loss = 1.35 and accuracy of 0.55
# Iteration 700: with minibatch training loss = 1.15 and accuracy of 0.56
# Epoch 1, Overall loss = 1.15 and accuracy of 0.593
# Validation
# Epoch 1, Overall loss = 1.03 and accuracy of 0.666
# round  16
# Training
# Iteration 0: with minibatch training loss = 0.894 and accuracy of 0.72
# Iteration 100: with minibatch training loss = 1.33 and accuracy of 0.58
# Iteration 200: with minibatch training loss = 1.12 and accuracy of 0.61
# Iteration 300: with minibatch training loss = 1.08 and accuracy of 0.62
# Iteration 400: with minibatch training loss = 1.28 and accuracy of 0.47
# Iteration 500: with minibatch training loss = 1.09 and accuracy of 0.59
# Iteration 600: with minibatch training loss = 1.35 and accuracy of 0.53
# Iteration 700: with minibatch training loss = 1.14 and accuracy of 0.66
# Epoch 1, Overall loss = 1.13 and accuracy of 0.606
# Validation
# Epoch 1, Overall loss = 1.04 and accuracy of 0.671
# round  17
# Training
# Iteration 0: with minibatch training loss = 1.21 and accuracy of 0.56
# Iteration 100: with minibatch training loss = 1.19 and accuracy of 0.64
# Iteration 200: with minibatch training loss = 1.07 and accuracy of 0.75
# Iteration 300: with minibatch training loss = 1.17 and accuracy of 0.56
# Iteration 400: with minibatch training loss = 1.18 and accuracy of 0.61
# Iteration 500: with minibatch training loss = 1.1 and accuracy of 0.62
# Iteration 600: with minibatch training loss = 1.12 and accuracy of 0.66
# Iteration 700: with minibatch training loss = 1.26 and accuracy of 0.62
# Epoch 1, Overall loss = 1.11 and accuracy of 0.609
# Validation
# Epoch 1, Overall loss = 1.01 and accuracy of 0.677
# round  18
# Training
# Iteration 0: with minibatch training loss = 1.11 and accuracy of 0.61
# Iteration 100: with minibatch training loss = 1.05 and accuracy of 0.64
# Iteration 200: with minibatch training loss = 0.697 and accuracy of 0.72
# Iteration 300: with minibatch training loss = 0.684 and accuracy of 0.8
# Iteration 400: with minibatch training loss = 1.18 and accuracy of 0.5
# Iteration 500: with minibatch training loss = 1.35 and accuracy of 0.55
# Iteration 600: with minibatch training loss = 1.05 and accuracy of 0.62
# Iteration 700: with minibatch training loss = 1.17 and accuracy of 0.59
# Epoch 1, Overall loss = 1.08 and accuracy of 0.62
# Validation
# Epoch 1, Overall loss = 1.01 and accuracy of 0.673
# round  19
# Training
# Iteration 0: with minibatch training loss = 1.19 and accuracy of 0.62
# Iteration 100: with minibatch training loss = 1.19 and accuracy of 0.56
# Iteration 200: with minibatch training loss = 1.1 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 1.14 and accuracy of 0.53
# Iteration 400: with minibatch training loss = 0.926 and accuracy of 0.67
# Iteration 500: with minibatch training loss = 1.24 and accuracy of 0.59
# Iteration 600: with minibatch training loss = 1.23 and accuracy of 0.59
# Iteration 700: with minibatch training loss = 1.19 and accuracy of 0.59
# Epoch 1, Overall loss = 1.06 and accuracy of 0.626
# Validation
# Epoch 1, Overall loss = 0.971 and accuracy of 0.68
# round  20
# Training
# Iteration 0: with minibatch training loss = 1 and accuracy of 0.59
# Iteration 100: with minibatch training loss = 1.11 and accuracy of 0.64
# Iteration 200: with minibatch training loss = 0.999 and accuracy of 0.66
# Iteration 300: with minibatch training loss = 1.08 and accuracy of 0.66
# Iteration 400: with minibatch training loss = 0.993 and accuracy of 0.67
# Iteration 500: with minibatch training loss = 0.999 and accuracy of 0.69
# Iteration 600: with minibatch training loss = 1.05 and accuracy of 0.61
# Iteration 700: with minibatch training loss = 1 and accuracy of 0.69
# Epoch 1, Overall loss = 1.05 and accuracy of 0.633
# Validation
# Epoch 1, Overall loss = 0.971 and accuracy of 0.683
# round  21
# Training
# Iteration 0: with minibatch training loss = 0.787 and accuracy of 0.78
# Iteration 100: with minibatch training loss = 1.07 and accuracy of 0.59
# Iteration 200: with minibatch training loss = 1.05 and accuracy of 0.62
# Iteration 300: with minibatch training loss = 0.853 and accuracy of 0.67
# Iteration 400: with minibatch training loss = 0.848 and accuracy of 0.7
# Iteration 500: with minibatch training loss = 0.887 and accuracy of 0.66
# Iteration 600: with minibatch training loss = 1 and accuracy of 0.59
# Iteration 700: with minibatch training loss = 1.08 and accuracy of 0.62
# Epoch 1, Overall loss = 1.03 and accuracy of 0.637
# Validation
# Epoch 1, Overall loss = 0.952 and accuracy of 0.686
# round  22
# Training
# Iteration 0: with minibatch training loss = 0.924 and accuracy of 0.72
# Iteration 100: with minibatch training loss = 0.764 and accuracy of 0.73
# Iteration 200: with minibatch training loss = 1.01 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 0.994 and accuracy of 0.67
# Iteration 400: with minibatch training loss = 0.794 and accuracy of 0.73
# Iteration 500: with minibatch training loss = 1.23 and accuracy of 0.61
# Iteration 600: with minibatch training loss = 0.782 and accuracy of 0.75
# Iteration 700: with minibatch training loss = 0.95 and accuracy of 0.62
# Epoch 1, Overall loss = 1.01 and accuracy of 0.646
# Validation
# Epoch 1, Overall loss = 0.94 and accuracy of 0.693
# round  23
# Training
# Iteration 0: with minibatch training loss = 0.847 and accuracy of 0.75
# Iteration 100: with minibatch training loss = 1.27 and accuracy of 0.53
# Iteration 200: with minibatch training loss = 0.892 and accuracy of 0.73
# Iteration 300: with minibatch training loss = 1.17 and accuracy of 0.55
# Iteration 400: with minibatch training loss = 1.01 and accuracy of 0.7
# Iteration 500: with minibatch training loss = 0.949 and accuracy of 0.72
# Iteration 600: with minibatch training loss = 0.974 and accuracy of 0.69
# Iteration 700: with minibatch training loss = 0.948 and accuracy of 0.7
# Epoch 1, Overall loss = 0.992 and accuracy of 0.648
# Validation
# Epoch 1, Overall loss = 0.922 and accuracy of 0.693
# round  24
# Training
# Iteration 0: with minibatch training loss = 1.02 and accuracy of 0.62
# Iteration 100: with minibatch training loss = 1.01 and accuracy of 0.67
# Iteration 200: with minibatch training loss = 1.05 and accuracy of 0.55
# Iteration 300: with minibatch training loss = 0.945 and accuracy of 0.64
# Iteration 400: with minibatch training loss = 0.936 and accuracy of 0.62
# Iteration 500: with minibatch training loss = 0.961 and accuracy of 0.67
# Iteration 600: with minibatch training loss = 0.847 and accuracy of 0.72
# Iteration 700: with minibatch training loss = 0.914 and accuracy of 0.73
# Epoch 1, Overall loss = 0.974 and accuracy of 0.657
# Validation
# Epoch 1, Overall loss = 0.908 and accuracy of 0.702
# round  25
# Training
# Iteration 0: with minibatch training loss = 0.782 and accuracy of 0.7
# Iteration 100: with minibatch training loss = 0.858 and accuracy of 0.69
# Iteration 200: with minibatch training loss = 1.36 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 1.11 and accuracy of 0.56
# Iteration 400: with minibatch training loss = 0.822 and accuracy of 0.67
# Iteration 500: with minibatch training loss = 1.08 and accuracy of 0.59
# Iteration 600: with minibatch training loss = 0.999 and accuracy of 0.73
# Iteration 700: with minibatch training loss = 1.14 and accuracy of 0.61
# Epoch 1, Overall loss = 0.964 and accuracy of 0.661
# Validation
# Epoch 1, Overall loss = 0.906 and accuracy of 0.708
# round  26
# Training
# Iteration 0: with minibatch training loss = 1.02 and accuracy of 0.61
# Iteration 100: with minibatch training loss = 0.925 and accuracy of 0.69
# Iteration 200: with minibatch training loss = 0.936 and accuracy of 0.72
# Iteration 300: with minibatch training loss = 1.06 and accuracy of 0.59
# Iteration 400: with minibatch training loss = 0.971 and accuracy of 0.64
# Iteration 500: with minibatch training loss = 0.817 and accuracy of 0.72
# Iteration 600: with minibatch training loss = 0.971 and accuracy of 0.66
# Iteration 700: with minibatch training loss = 0.862 and accuracy of 0.72
# Epoch 1, Overall loss = 0.952 and accuracy of 0.666
# Validation
# Epoch 1, Overall loss = 0.887 and accuracy of 0.725
# round  27
# Training
# Iteration 0: with minibatch training loss = 0.974 and accuracy of 0.62
# Iteration 100: with minibatch training loss = 0.847 and accuracy of 0.78
# Iteration 200: with minibatch training loss = 0.893 and accuracy of 0.69
# Iteration 300: with minibatch training loss = 1.33 and accuracy of 0.53
# Iteration 400: with minibatch training loss = 0.667 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 1.16 and accuracy of 0.62
# Iteration 600: with minibatch training loss = 1.03 and accuracy of 0.66
# Iteration 700: with minibatch training loss = 0.94 and accuracy of 0.66
# Epoch 1, Overall loss = 0.938 and accuracy of 0.669
# Validation
# Epoch 1, Overall loss = 0.865 and accuracy of 0.717
# round  28
# Training
# Iteration 0: with minibatch training loss = 0.946 and accuracy of 0.72
# Iteration 100: with minibatch training loss = 1.02 and accuracy of 0.58
# Iteration 200: with minibatch training loss = 0.678 and accuracy of 0.77
# Iteration 300: with minibatch training loss = 0.818 and accuracy of 0.69
# Iteration 400: with minibatch training loss = 1.07 and accuracy of 0.66
# Iteration 500: with minibatch training loss = 0.801 and accuracy of 0.73
# Iteration 600: with minibatch training loss = 0.915 and accuracy of 0.7
# Iteration 700: with minibatch training loss = 0.904 and accuracy of 0.69
# Epoch 1, Overall loss = 0.916 and accuracy of 0.678
# Validation
# Epoch 1, Overall loss = 0.877 and accuracy of 0.722
# round  29
# Training
# Iteration 0: with minibatch training loss = 0.982 and accuracy of 0.69
# Iteration 100: with minibatch training loss = 0.793 and accuracy of 0.8
# Iteration 200: with minibatch training loss = 0.926 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 1.08 and accuracy of 0.62
# Iteration 400: with minibatch training loss = 1.2 and accuracy of 0.58
# Iteration 500: with minibatch training loss = 0.804 and accuracy of 0.69
# Iteration 600: with minibatch training loss = 0.831 and accuracy of 0.73
# Iteration 700: with minibatch training loss = 0.705 and accuracy of 0.77
# Epoch 1, Overall loss = 0.914 and accuracy of 0.676
# Validation
# Epoch 1, Overall loss = 0.869 and accuracy of 0.722
# round  30
# Training
# Iteration 0: with minibatch training loss = 0.939 and accuracy of 0.73
# Iteration 100: with minibatch training loss = 0.677 and accuracy of 0.77
# Iteration 200: with minibatch training loss = 1.2 and accuracy of 0.59
# Iteration 300: with minibatch training loss = 1.24 and accuracy of 0.55
# Iteration 400: with minibatch training loss = 0.908 and accuracy of 0.72
# Iteration 500: with minibatch training loss = 0.998 and accuracy of 0.64
# Iteration 600: with minibatch training loss = 0.739 and accuracy of 0.73
# Iteration 700: with minibatch training loss = 0.973 and accuracy of 0.59
# Epoch 1, Overall loss = 0.903 and accuracy of 0.683
# Validation
# Epoch 1, Overall loss = 0.841 and accuracy of 0.744
# round  31
# Training
# Iteration 0: with minibatch training loss = 0.753 and accuracy of 0.69
# Iteration 100: with minibatch training loss = 1.09 and accuracy of 0.64
# Iteration 200: with minibatch training loss = 0.766 and accuracy of 0.72
# Iteration 300: with minibatch training loss = 0.954 and accuracy of 0.61
# Iteration 400: with minibatch training loss = 0.938 and accuracy of 0.62
# Iteration 500: with minibatch training loss = 0.899 and accuracy of 0.75
# Iteration 600: with minibatch training loss = 0.965 and accuracy of 0.62
# Iteration 700: with minibatch training loss = 0.744 and accuracy of 0.69
# Epoch 1, Overall loss = 0.89 and accuracy of 0.687
# Validation
# Epoch 1, Overall loss = 0.84 and accuracy of 0.735
# round  32
# Training
# Iteration 0: with minibatch training loss = 0.909 and accuracy of 0.69
# Iteration 100: with minibatch training loss = 0.666 and accuracy of 0.78
# Iteration 200: with minibatch training loss = 0.965 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 0.722 and accuracy of 0.72
# Iteration 400: with minibatch training loss = 0.729 and accuracy of 0.72
# Iteration 500: with minibatch training loss = 0.796 and accuracy of 0.67
# Iteration 600: with minibatch training loss = 0.839 and accuracy of 0.64
# Iteration 700: with minibatch training loss = 0.833 and accuracy of 0.75
# Epoch 1, Overall loss = 0.881 and accuracy of 0.691
# Validation
# Epoch 1, Overall loss = 0.857 and accuracy of 0.715
# round  33
# Training
# Iteration 0: with minibatch training loss = 0.954 and accuracy of 0.62
# Iteration 100: with minibatch training loss = 0.852 and accuracy of 0.72
# Iteration 200: with minibatch training loss = 0.958 and accuracy of 0.72
# Iteration 300: with minibatch training loss = 1.03 and accuracy of 0.58
# Iteration 400: with minibatch training loss = 1.05 and accuracy of 0.59
# Iteration 500: with minibatch training loss = 0.705 and accuracy of 0.7
# Iteration 600: with minibatch training loss = 0.936 and accuracy of 0.61
# Iteration 700: with minibatch training loss = 1.44 and accuracy of 0.59
# Epoch 1, Overall loss = 0.868 and accuracy of 0.695
# Validation
# Epoch 1, Overall loss = 0.827 and accuracy of 0.724
# round  34
# Training
# Iteration 0: with minibatch training loss = 0.749 and accuracy of 0.66
# Iteration 100: with minibatch training loss = 0.88 and accuracy of 0.67
# Iteration 200: with minibatch training loss = 1.1 and accuracy of 0.62
# Iteration 300: with minibatch training loss = 0.738 and accuracy of 0.73
# Iteration 400: with minibatch training loss = 0.886 and accuracy of 0.66
# Iteration 500: with minibatch training loss = 0.817 and accuracy of 0.77
# Iteration 600: with minibatch training loss = 1.07 and accuracy of 0.58
# Iteration 700: with minibatch training loss = 1 and accuracy of 0.67
# Epoch 1, Overall loss = 0.855 and accuracy of 0.699
# Validation
# Epoch 1, Overall loss = 0.823 and accuracy of 0.736
# round  35
# Training
# Iteration 0: with minibatch training loss = 0.759 and accuracy of 0.73
# Iteration 100: with minibatch training loss = 0.886 and accuracy of 0.66
# Iteration 200: with minibatch training loss = 0.97 and accuracy of 0.66
# Iteration 300: with minibatch training loss = 0.824 and accuracy of 0.69
# Iteration 400: with minibatch training loss = 0.831 and accuracy of 0.77
# Iteration 500: with minibatch training loss = 1.15 and accuracy of 0.62
# Iteration 600: with minibatch training loss = 0.854 and accuracy of 0.7
# Iteration 700: with minibatch training loss = 0.586 and accuracy of 0.8
# Epoch 1, Overall loss = 0.85 and accuracy of 0.702
# Validation
# Epoch 1, Overall loss = 0.826 and accuracy of 0.736
# round  36
# Training
# Iteration 0: with minibatch training loss = 0.786 and accuracy of 0.7
# Iteration 100: with minibatch training loss = 1.07 and accuracy of 0.73
# Iteration 200: with minibatch training loss = 0.66 and accuracy of 0.75
# Iteration 300: with minibatch training loss = 1.28 and accuracy of 0.59
# Iteration 400: with minibatch training loss = 0.754 and accuracy of 0.7
# Iteration 500: with minibatch training loss = 1.05 and accuracy of 0.66
# Iteration 600: with minibatch training loss = 0.985 and accuracy of 0.61
# Iteration 700: with minibatch training loss = 0.765 and accuracy of 0.73
# Epoch 1, Overall loss = 0.839 and accuracy of 0.706
# Validation
# Epoch 1, Overall loss = 0.87 and accuracy of 0.724
# round  37
# Training
# Iteration 0: with minibatch training loss = 0.92 and accuracy of 0.66
# Iteration 100: with minibatch training loss = 0.791 and accuracy of 0.72
# Iteration 200: with minibatch training loss = 0.923 and accuracy of 0.69
# Iteration 300: with minibatch training loss = 0.653 and accuracy of 0.81
# Iteration 400: with minibatch training loss = 0.743 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.772 and accuracy of 0.7
# Iteration 600: with minibatch training loss = 0.961 and accuracy of 0.73
# Iteration 700: with minibatch training loss = 0.827 and accuracy of 0.75
# Epoch 1, Overall loss = 0.832 and accuracy of 0.709
# Validation
# Epoch 1, Overall loss = 0.842 and accuracy of 0.732
# round  38
# Training
# Iteration 0: with minibatch training loss = 0.766 and accuracy of 0.69
# Iteration 100: with minibatch training loss = 0.796 and accuracy of 0.7
# Iteration 200: with minibatch training loss = 0.861 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 0.914 and accuracy of 0.72
# Iteration 400: with minibatch training loss = 0.634 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.825 and accuracy of 0.66
# Iteration 600: with minibatch training loss = 0.739 and accuracy of 0.67
# Iteration 700: with minibatch training loss = 0.692 and accuracy of 0.73
# Epoch 1, Overall loss = 0.816 and accuracy of 0.71
# Validation
# Epoch 1, Overall loss = 0.84 and accuracy of 0.725
# round  39
# Training
# Iteration 0: with minibatch training loss = 0.64 and accuracy of 0.78
# Iteration 100: with minibatch training loss = 0.648 and accuracy of 0.77
# Iteration 200: with minibatch training loss = 0.781 and accuracy of 0.69
# Iteration 300: with minibatch training loss = 0.815 and accuracy of 0.62
# Iteration 400: with minibatch training loss = 0.758 and accuracy of 0.73
# Iteration 500: with minibatch training loss = 0.709 and accuracy of 0.8
# Iteration 600: with minibatch training loss = 0.983 and accuracy of 0.7
# Iteration 700: with minibatch training loss = 0.747 and accuracy of 0.73
# Epoch 1, Overall loss = 0.817 and accuracy of 0.711
# Validation
# Epoch 1, Overall loss = 0.817 and accuracy of 0.741
# round  40
# Training
# Iteration 0: with minibatch training loss = 0.722 and accuracy of 0.72
# Iteration 100: with minibatch training loss = 0.845 and accuracy of 0.72
# Iteration 200: with minibatch training loss = 0.73 and accuracy of 0.72
# Iteration 300: with minibatch training loss = 0.744 and accuracy of 0.75
# Iteration 400: with minibatch training loss = 0.672 and accuracy of 0.78
# Iteration 500: with minibatch training loss = 0.84 and accuracy of 0.66
# Iteration 600: with minibatch training loss = 0.769 and accuracy of 0.69
# Iteration 700: with minibatch training loss = 0.774 and accuracy of 0.67
# Epoch 1, Overall loss = 0.808 and accuracy of 0.716
# Validation
# Epoch 1, Overall loss = 0.808 and accuracy of 0.744
# round  41
# Training
# Iteration 0: with minibatch training loss = 0.668 and accuracy of 0.78
# Iteration 100: with minibatch training loss = 0.564 and accuracy of 0.78
# Iteration 200: with minibatch training loss = 0.939 and accuracy of 0.67
# Iteration 300: with minibatch training loss = 0.73 and accuracy of 0.72
# Iteration 400: with minibatch training loss = 0.653 and accuracy of 0.77
# Iteration 500: with minibatch training loss = 0.969 and accuracy of 0.62
# Iteration 600: with minibatch training loss = 0.691 and accuracy of 0.8
# Iteration 700: with minibatch training loss = 1.05 and accuracy of 0.72
# Epoch 1, Overall loss = 0.794 and accuracy of 0.722
# Validation
# Epoch 1, Overall loss = 0.81 and accuracy of 0.74
# round  42
# Training
# Iteration 0: with minibatch training loss = 0.728 and accuracy of 0.69
# Iteration 100: with minibatch training loss = 0.727 and accuracy of 0.72
# Iteration 200: with minibatch training loss = 0.617 and accuracy of 0.72
# Iteration 300: with minibatch training loss = 0.991 and accuracy of 0.67
# Iteration 400: with minibatch training loss = 0.949 and accuracy of 0.66
# Iteration 500: with minibatch training loss = 0.924 and accuracy of 0.59
# Iteration 600: with minibatch training loss = 0.545 and accuracy of 0.78
# Iteration 700: with minibatch training loss = 0.741 and accuracy of 0.8
# Epoch 1, Overall loss = 0.786 and accuracy of 0.722
# Validation
# Epoch 1, Overall loss = 0.821 and accuracy of 0.739
# round  43
# Training
# Iteration 0: with minibatch training loss = 0.57 and accuracy of 0.8
# Iteration 100: with minibatch training loss = 0.675 and accuracy of 0.77
# Iteration 200: with minibatch training loss = 0.879 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 0.717 and accuracy of 0.78
# Iteration 400: with minibatch training loss = 0.674 and accuracy of 0.73
# Iteration 500: with minibatch training loss = 0.745 and accuracy of 0.7
# Iteration 600: with minibatch training loss = 0.605 and accuracy of 0.83
# Iteration 700: with minibatch training loss = 0.564 and accuracy of 0.75
# Epoch 1, Overall loss = 0.783 and accuracy of 0.723
# Validation
# Epoch 1, Overall loss = 0.793 and accuracy of 0.732
# round  44
# Training
# Iteration 0: with minibatch training loss = 0.668 and accuracy of 0.78
# Iteration 100: with minibatch training loss = 0.756 and accuracy of 0.73
# Iteration 200: with minibatch training loss = 0.805 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 1.03 and accuracy of 0.64
# Iteration 400: with minibatch training loss = 0.694 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.714 and accuracy of 0.8
# Iteration 600: with minibatch training loss = 0.513 and accuracy of 0.81
# Iteration 700: with minibatch training loss = 1.14 and accuracy of 0.58
# Epoch 1, Overall loss = 0.768 and accuracy of 0.731
# Validation
# Epoch 1, Overall loss = 0.786 and accuracy of 0.755
# round  45
# Training
# Iteration 0: with minibatch training loss = 0.671 and accuracy of 0.8
# Iteration 100: with minibatch training loss = 0.871 and accuracy of 0.75
# Iteration 200: with minibatch training loss = 0.692 and accuracy of 0.81
# Iteration 300: with minibatch training loss = 0.759 and accuracy of 0.73
# Iteration 400: with minibatch training loss = 0.701 and accuracy of 0.81
# Iteration 500: with minibatch training loss = 0.868 and accuracy of 0.72
# Iteration 600: with minibatch training loss = 0.925 and accuracy of 0.66
# Iteration 700: with minibatch training loss = 0.822 and accuracy of 0.77
# Epoch 1, Overall loss = 0.762 and accuracy of 0.729
# Validation
# Epoch 1, Overall loss = 0.781 and accuracy of 0.757
# round  46
# Training
# Iteration 0: with minibatch training loss = 0.761 and accuracy of 0.77
# Iteration 100: with minibatch training loss = 0.692 and accuracy of 0.75
# Iteration 200: with minibatch training loss = 0.72 and accuracy of 0.72
# Iteration 300: with minibatch training loss = 0.85 and accuracy of 0.66
# Iteration 400: with minibatch training loss = 0.678 and accuracy of 0.8
# Iteration 500: with minibatch training loss = 0.777 and accuracy of 0.72
# Iteration 600: with minibatch training loss = 0.783 and accuracy of 0.72
# Iteration 700: with minibatch training loss = 0.679 and accuracy of 0.77
# Epoch 1, Overall loss = 0.756 and accuracy of 0.737
# Validation
# Epoch 1, Overall loss = 0.783 and accuracy of 0.747
# round  47
# Training
# Iteration 0: with minibatch training loss = 0.736 and accuracy of 0.7
# Iteration 100: with minibatch training loss = 0.623 and accuracy of 0.77
# Iteration 200: with minibatch training loss = 0.766 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 0.634 and accuracy of 0.73
# Iteration 400: with minibatch training loss = 0.672 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.712 and accuracy of 0.78
# Iteration 600: with minibatch training loss = 0.726 and accuracy of 0.72
# Iteration 700: with minibatch training loss = 0.806 and accuracy of 0.7
# Epoch 1, Overall loss = 0.747 and accuracy of 0.737
# Validation
# Epoch 1, Overall loss = 0.792 and accuracy of 0.743
# round  48
# Training
# Iteration 0: with minibatch training loss = 0.992 and accuracy of 0.67
# Iteration 100: with minibatch training loss = 0.502 and accuracy of 0.84
# Iteration 200: with minibatch training loss = 0.997 and accuracy of 0.66
# Iteration 300: with minibatch training loss = 0.656 and accuracy of 0.72
# Iteration 400: with minibatch training loss = 0.762 and accuracy of 0.72
# Iteration 500: with minibatch training loss = 0.684 and accuracy of 0.73
# Iteration 600: with minibatch training loss = 0.763 and accuracy of 0.75
# Iteration 700: with minibatch training loss = 0.821 and accuracy of 0.64
# Epoch 1, Overall loss = 0.744 and accuracy of 0.739
# Validation
# Epoch 1, Overall loss = 0.761 and accuracy of 0.759
# round  49
# Training
# Iteration 0: with minibatch training loss = 0.841 and accuracy of 0.67
# Iteration 100: with minibatch training loss = 0.79 and accuracy of 0.75
# Iteration 200: with minibatch training loss = 0.894 and accuracy of 0.64
# Iteration 300: with minibatch training loss = 0.629 and accuracy of 0.77
# Iteration 400: with minibatch training loss = 0.712 and accuracy of 0.8
# Iteration 500: with minibatch training loss = 0.86 and accuracy of 0.62
# Iteration 600: with minibatch training loss = 0.821 and accuracy of 0.75
# Iteration 700: with minibatch training loss = 0.757 and accuracy of 0.73
# Epoch 1, Overall loss = 0.739 and accuracy of 0.739
# Validation
# Epoch 1, Overall loss = 0.766 and accuracy of 0.757
# round  50
# Training
# Iteration 0: with minibatch training loss = 0.842 and accuracy of 0.69
# Iteration 100: with minibatch training loss = 0.635 and accuracy of 0.72
# Iteration 200: with minibatch training loss = 0.711 and accuracy of 0.73
# Iteration 300: with minibatch training loss = 0.639 and accuracy of 0.83
# Iteration 400: with minibatch training loss = 0.768 and accuracy of 0.72
# Iteration 500: with minibatch training loss = 0.747 and accuracy of 0.75
# Iteration 600: with minibatch training loss = 0.924 and accuracy of 0.64
# Iteration 700: with minibatch training loss = 0.619 and accuracy of 0.81
# Epoch 1, Overall loss = 0.736 and accuracy of 0.74
# Validation
# Epoch 1, Overall loss = 0.753 and accuracy of 0.77
# round  51
# Training
# Iteration 0: with minibatch training loss = 0.849 and accuracy of 0.77
# Iteration 100: with minibatch training loss = 0.572 and accuracy of 0.83
# Iteration 200: with minibatch training loss = 0.823 and accuracy of 0.69
# Iteration 300: with minibatch training loss = 0.923 and accuracy of 0.69
# Iteration 400: with minibatch training loss = 0.812 and accuracy of 0.72
# Iteration 500: with minibatch training loss = 0.6 and accuracy of 0.72
# Iteration 600: with minibatch training loss = 0.672 and accuracy of 0.77
# Iteration 700: with minibatch training loss = 0.609 and accuracy of 0.78
# Epoch 1, Overall loss = 0.719 and accuracy of 0.748
# Validation
# Epoch 1, Overall loss = 0.767 and accuracy of 0.765
# round  52
# Training
# Iteration 0: with minibatch training loss = 0.701 and accuracy of 0.81
# Iteration 100: with minibatch training loss = 0.485 and accuracy of 0.84
# Iteration 200: with minibatch training loss = 0.538 and accuracy of 0.84
# Iteration 300: with minibatch training loss = 0.677 and accuracy of 0.83
# Iteration 400: with minibatch training loss = 0.703 and accuracy of 0.72
# Iteration 500: with minibatch training loss = 0.546 and accuracy of 0.83
# Iteration 600: with minibatch training loss = 0.702 and accuracy of 0.72
# Iteration 700: with minibatch training loss = 0.777 and accuracy of 0.69
# Epoch 1, Overall loss = 0.717 and accuracy of 0.75
# Validation
# Epoch 1, Overall loss = 0.769 and accuracy of 0.764
# round  53
# Training
# Iteration 0: with minibatch training loss = 0.693 and accuracy of 0.7
# Iteration 100: with minibatch training loss = 0.765 and accuracy of 0.73
# Iteration 200: with minibatch training loss = 0.729 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 0.698 and accuracy of 0.73
# Iteration 400: with minibatch training loss = 0.688 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.699 and accuracy of 0.77
# Iteration 600: with minibatch training loss = 0.726 and accuracy of 0.75
# Iteration 700: with minibatch training loss = 0.667 and accuracy of 0.81
# Epoch 1, Overall loss = 0.712 and accuracy of 0.751
# Validation
# Epoch 1, Overall loss = 0.769 and accuracy of 0.761
# round  54
# Training
# Iteration 0: with minibatch training loss = 0.587 and accuracy of 0.75
# Iteration 100: with minibatch training loss = 0.736 and accuracy of 0.73
# Iteration 200: with minibatch training loss = 0.71 and accuracy of 0.77
# Iteration 300: with minibatch training loss = 0.805 and accuracy of 0.77
# Iteration 400: with minibatch training loss = 0.571 and accuracy of 0.8
# Iteration 500: with minibatch training loss = 0.543 and accuracy of 0.86
# Iteration 600: with minibatch training loss = 0.597 and accuracy of 0.83
# Iteration 700: with minibatch training loss = 0.905 and accuracy of 0.56
# Epoch 1, Overall loss = 0.711 and accuracy of 0.749
# Validation
# Epoch 1, Overall loss = 0.746 and accuracy of 0.764
# round  55
# Training
# Iteration 0: with minibatch training loss = 0.771 and accuracy of 0.73
# Iteration 100: with minibatch training loss = 0.86 and accuracy of 0.66
# Iteration 200: with minibatch training loss = 0.708 and accuracy of 0.75
# Iteration 300: with minibatch training loss = 0.496 and accuracy of 0.83
# Iteration 400: with minibatch training loss = 0.744 and accuracy of 0.64
# Iteration 500: with minibatch training loss = 0.62 and accuracy of 0.8
# Iteration 600: with minibatch training loss = 0.947 and accuracy of 0.67
# Iteration 700: with minibatch training loss = 0.902 and accuracy of 0.7
# Epoch 1, Overall loss = 0.708 and accuracy of 0.749
# Validation
# Epoch 1, Overall loss = 0.743 and accuracy of 0.767
# round  56
# Training
# Iteration 0: with minibatch training loss = 0.73 and accuracy of 0.77
# Iteration 100: with minibatch training loss = 1 and accuracy of 0.61
# Iteration 200: with minibatch training loss = 0.766 and accuracy of 0.73
# Iteration 300: with minibatch training loss = 0.727 and accuracy of 0.7
# Iteration 400: with minibatch training loss = 0.709 and accuracy of 0.81
# Iteration 500: with minibatch training loss = 0.487 and accuracy of 0.88
# Iteration 600: with minibatch training loss = 0.712 and accuracy of 0.72
# Iteration 700: with minibatch training loss = 0.817 and accuracy of 0.75
# Epoch 1, Overall loss = 0.704 and accuracy of 0.753
# Validation
# Epoch 1, Overall loss = 0.751 and accuracy of 0.763
# round  57
# Training
# Iteration 0: with minibatch training loss = 0.631 and accuracy of 0.81
# Iteration 100: with minibatch training loss = 0.76 and accuracy of 0.7
# Iteration 200: with minibatch training loss = 0.581 and accuracy of 0.77
# Iteration 300: with minibatch training loss = 0.536 and accuracy of 0.77
# Iteration 400: with minibatch training loss = 0.639 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.535 and accuracy of 0.84
# Iteration 600: with minibatch training loss = 0.511 and accuracy of 0.84
# Iteration 700: with minibatch training loss = 0.646 and accuracy of 0.77
# Epoch 1, Overall loss = 0.692 and accuracy of 0.756
# Validation
# Epoch 1, Overall loss = 0.765 and accuracy of 0.75
# round  58
# Training
# Iteration 0: with minibatch training loss = 0.886 and accuracy of 0.73
# Iteration 100: with minibatch training loss = 0.625 and accuracy of 0.81
# Iteration 200: with minibatch training loss = 0.843 and accuracy of 0.75
# Iteration 300: with minibatch training loss = 0.455 and accuracy of 0.81
# Iteration 400: with minibatch training loss = 0.683 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.841 and accuracy of 0.75
# Iteration 600: with minibatch training loss = 0.512 and accuracy of 0.81
# Iteration 700: with minibatch training loss = 0.546 and accuracy of 0.78
# Epoch 1, Overall loss = 0.691 and accuracy of 0.757
# Validation
# Epoch 1, Overall loss = 0.744 and accuracy of 0.762
# round  59
# Training
# Iteration 0: with minibatch training loss = 0.576 and accuracy of 0.78
# Iteration 100: with minibatch training loss = 0.742 and accuracy of 0.72
# Iteration 200: with minibatch training loss = 0.761 and accuracy of 0.73
# Iteration 300: with minibatch training loss = 0.782 and accuracy of 0.73
# Iteration 400: with minibatch training loss = 0.734 and accuracy of 0.72
# Iteration 500: with minibatch training loss = 0.615 and accuracy of 0.73
# Iteration 600: with minibatch training loss = 0.718 and accuracy of 0.73
# Iteration 700: with minibatch training loss = 0.715 and accuracy of 0.75
# Epoch 1, Overall loss = 0.68 and accuracy of 0.761
# Validation
# Epoch 1, Overall loss = 0.76 and accuracy of 0.769
# round  60
# Training
# Iteration 0: with minibatch training loss = 0.841 and accuracy of 0.66
# Iteration 100: with minibatch training loss = 0.594 and accuracy of 0.78
# Iteration 200: with minibatch training loss = 0.619 and accuracy of 0.8
# Iteration 300: with minibatch training loss = 0.855 and accuracy of 0.73
# Iteration 400: with minibatch training loss = 0.522 and accuracy of 0.83
# Iteration 500: with minibatch training loss = 0.938 and accuracy of 0.59
# Iteration 600: with minibatch training loss = 0.837 and accuracy of 0.69
# Iteration 700: with minibatch training loss = 0.534 and accuracy of 0.78
# Epoch 1, Overall loss = 0.679 and accuracy of 0.757
# Validation
# Epoch 1, Overall loss = 0.769 and accuracy of 0.762
# round  61
# Training
# Iteration 0: with minibatch training loss = 0.837 and accuracy of 0.77
# Iteration 100: with minibatch training loss = 0.797 and accuracy of 0.78
# Iteration 200: with minibatch training loss = 0.533 and accuracy of 0.83
# Iteration 300: with minibatch training loss = 0.632 and accuracy of 0.8
# Iteration 400: with minibatch training loss = 0.567 and accuracy of 0.81
# Iteration 500: with minibatch training loss = 0.573 and accuracy of 0.75
# Iteration 600: with minibatch training loss = 0.507 and accuracy of 0.84
# Iteration 700: with minibatch training loss = 0.813 and accuracy of 0.73
# Epoch 1, Overall loss = 0.679 and accuracy of 0.762
# Validation
# Epoch 1, Overall loss = 0.763 and accuracy of 0.746
# round  62
# Training
# Iteration 0: with minibatch training loss = 0.935 and accuracy of 0.67
# Iteration 100: with minibatch training loss = 0.621 and accuracy of 0.78
# Iteration 200: with minibatch training loss = 0.745 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 0.571 and accuracy of 0.8
# Iteration 400: with minibatch training loss = 0.485 and accuracy of 0.83
# Iteration 500: with minibatch training loss = 0.798 and accuracy of 0.77
# Iteration 600: with minibatch training loss = 0.589 and accuracy of 0.77
# Iteration 700: with minibatch training loss = 0.643 and accuracy of 0.77
# Epoch 1, Overall loss = 0.668 and accuracy of 0.764
# Validation
# Epoch 1, Overall loss = 0.749 and accuracy of 0.763
# round  63
# Training
# Iteration 0: with minibatch training loss = 0.862 and accuracy of 0.72
# Iteration 100: with minibatch training loss = 0.575 and accuracy of 0.81
# Iteration 200: with minibatch training loss = 0.78 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 0.625 and accuracy of 0.72
# Iteration 400: with minibatch training loss = 0.51 and accuracy of 0.8
# Iteration 500: with minibatch training loss = 0.723 and accuracy of 0.81
# Iteration 600: with minibatch training loss = 0.79 and accuracy of 0.73
# Iteration 700: with minibatch training loss = 0.604 and accuracy of 0.77
# Epoch 1, Overall loss = 0.667 and accuracy of 0.764
# Validation
# Epoch 1, Overall loss = 0.752 and accuracy of 0.759
# round  64
# Training
# Iteration 0: with minibatch training loss = 0.643 and accuracy of 0.78
# Iteration 100: with minibatch training loss = 0.593 and accuracy of 0.77
# Iteration 200: with minibatch training loss = 0.545 and accuracy of 0.8
# Iteration 300: with minibatch training loss = 0.882 and accuracy of 0.77
# Iteration 400: with minibatch training loss = 0.557 and accuracy of 0.77
# Iteration 500: with minibatch training loss = 0.562 and accuracy of 0.77
# Iteration 600: with minibatch training loss = 0.61 and accuracy of 0.78
# Iteration 700: with minibatch training loss = 0.548 and accuracy of 0.81
# Epoch 1, Overall loss = 0.666 and accuracy of 0.767
# Validation
# Epoch 1, Overall loss = 0.728 and accuracy of 0.768
# round  65
# Training
# Iteration 0: with minibatch training loss = 0.587 and accuracy of 0.8
# Iteration 100: with minibatch training loss = 0.68 and accuracy of 0.84
# Iteration 200: with minibatch training loss = 0.678 and accuracy of 0.73
# Iteration 300: with minibatch training loss = 0.445 and accuracy of 0.84
# Iteration 400: with minibatch training loss = 0.777 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.841 and accuracy of 0.7
# Iteration 600: with minibatch training loss = 0.943 and accuracy of 0.61
# Iteration 700: with minibatch training loss = 0.615 and accuracy of 0.8
# Epoch 1, Overall loss = 0.658 and accuracy of 0.769
# Validation
# Epoch 1, Overall loss = 0.75 and accuracy of 0.77
# round  66
# Training
# Iteration 0: with minibatch training loss = 0.854 and accuracy of 0.69
# Iteration 100: with minibatch training loss = 0.673 and accuracy of 0.7
# Iteration 200: with minibatch training loss = 0.684 and accuracy of 0.77
# Iteration 300: with minibatch training loss = 0.45 and accuracy of 0.86
# Iteration 400: with minibatch training loss = 0.689 and accuracy of 0.75
# Iteration 500: with minibatch training loss = 0.682 and accuracy of 0.77
# Iteration 600: with minibatch training loss = 0.486 and accuracy of 0.81
# Iteration 700: with minibatch training loss = 0.739 and accuracy of 0.73
# Epoch 1, Overall loss = 0.648 and accuracy of 0.772
# Validation
# Epoch 1, Overall loss = 0.723 and accuracy of 0.765
# round  67
# Training
# Iteration 0: with minibatch training loss = 0.595 and accuracy of 0.78
# Iteration 100: with minibatch training loss = 0.673 and accuracy of 0.75
# Iteration 200: with minibatch training loss = 0.677 and accuracy of 0.7
# Iteration 300: with minibatch training loss = 0.609 and accuracy of 0.75
# Iteration 400: with minibatch training loss = 0.758 and accuracy of 0.81
# Iteration 500: with minibatch training loss = 0.403 and accuracy of 0.8
# Iteration 600: with minibatch training loss = 0.756 and accuracy of 0.78
# Iteration 700: with minibatch training loss = 0.615 and accuracy of 0.77
# Epoch 1, Overall loss = 0.645 and accuracy of 0.775
# Validation
# Epoch 1, Overall loss = 0.747 and accuracy of 0.766
# round  68
# Training
# Iteration 0: with minibatch training loss = 0.529 and accuracy of 0.81
# Iteration 100: with minibatch training loss = 0.518 and accuracy of 0.84
# Iteration 200: with minibatch training loss = 0.717 and accuracy of 0.75
# Iteration 300: with minibatch training loss = 0.751 and accuracy of 0.72
# Iteration 400: with minibatch training loss = 0.565 and accuracy of 0.83
# Iteration 500: with minibatch training loss = 0.781 and accuracy of 0.75
# Iteration 600: with minibatch training loss = 0.687 and accuracy of 0.78
# Iteration 700: with minibatch training loss = 0.682 and accuracy of 0.73
# Epoch 1, Overall loss = 0.64 and accuracy of 0.776
# Validation
# Epoch 1, Overall loss = 0.74 and accuracy of 0.761
# round  69
# Training
# Iteration 0: with minibatch training loss = 0.579 and accuracy of 0.81
# Iteration 100: with minibatch training loss = 0.377 and accuracy of 0.86
# Iteration 200: with minibatch training loss = 0.629 and accuracy of 0.8
# Iteration 300: with minibatch training loss = 0.736 and accuracy of 0.75
# Iteration 400: with minibatch training loss = 0.549 and accuracy of 0.8
# Iteration 500: with minibatch training loss = 0.508 and accuracy of 0.83
# Iteration 600: with minibatch training loss = 0.655 and accuracy of 0.78
# Iteration 700: with minibatch training loss = 0.548 and accuracy of 0.8
# Epoch 1, Overall loss = 0.636 and accuracy of 0.776
# Validation
# Epoch 1, Overall loss = 0.741 and accuracy of 0.759

# %%
# Test your model here, and make sure 
# the output of this cell is the accuracy
# of your best model on the training and val sets
# We're looking for >= 70% accuracy on Validation
print('Training')
run_model(sess,y_out,mean_loss,X_train,y_train,1,64)
print('Validation')
run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Epoch 1, Overall loss = 0.372 and accuracy of 0.914
# Validation
# Epoch 1, Overall loss = 0.741 and accuracy of 0.759
# (0.74103022336959834, 0.75900000000000001)

# %% [markdown]
# ### Describe what you did here
# In this cell you should also write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network

# %% [markdown]
# _Tell us here_

# %% [markdown]
# ### Test Set - Do this only once
# Now that we've gotten a result that we're happy with, we test our final model on the test set. This would be the score we would achieve on a competition. Think about how this compares to your validation set accuracy.

# %%
print('Test')
run_model(sess,y_out,mean_loss,X_test,y_test,1,64)
# Out:
# Test
# Epoch 1, Overall loss = 0.734 and accuracy of 0.756
# (0.73406313457489014, 0.75580000000000003)

# %% [markdown]
# ## Going further with TensorFlow
#
# The next assignment will make heavy use of TensorFlow. You might also find it useful for your projects.

# %% [markdown]
# # Extra Credit Description
# If you implement any additional features for extra credit, clearly describe them here with pointers to any code in this or other files if applicable.
